# %%
from nltk.corpus import treebank
import nltk
from nltk import pos_tag, word_tokenize
from nltk.tag import CRFTagger, DefaultTagger
from nltk.tag.brill import BrillTagger
import re
import unicodedata
from nltk.tbl.template import Template
from nltk.tag.brill import Pos, Word
from nltk.tag import untag, RegexpTagger, BrillTaggerTrainer

from matplotlib import pyplot as plt
from nltk.tag.api import TaggerI

# %% [markdown]
# ### Data

# %%
train_sentences = treebank.tagged_sents()[:3000]
test_sentences = treebank.tagged_sents()[3000:]

# %% [markdown]
# ### Contextualized feature function

# %%
model_file = 'model3.crf.tagger'

# %%
pattern = re.compile(r"\d")

# %%
def get_basic_feature(token, preffix=''):
    feature_list = []
    
    if not token:
        return feature_list

    # Capitalization
    if token[0].isupper():
        feature_list.append(f"{preffix}_CAPITALIZATION")

    # Number
    if re.search(pattern, token) is not None:
        feature_list.append(f"{preffix}_HAS_NUM")

    # Punctuation
    punc_cat = {"Pc", "Pd", "Ps", "Pe", "Pi", "Pf", "Po"}
    if all(unicodedata.category(x) in punc_cat for x in token):
        feature_list.append(f"{preffix}_PUNCTUATION")

    # Suffix up to length 3
    if len(token) > 1:
        feature_list.append(f"{preffix}_SUF_" + token[-1:])
    if len(token) > 2:
        feature_list.append(f"{preffix}_SUF_" + token[-2:])
    if len(token) > 3:
        feature_list.append(f"{preffix}_SUF_" + token[-3:])

    feature_list.append(f"{preffix}_WORD_" + token)
    return feature_list

def get_context_feature(token, preffix=''):
    feature_list = []
    
    if not token:
        return feature_list

    # Number
    if re.search(pattern, token) is not None:
        feature_list.append(f"{preffix}_HAS_NUM")

    # Punctuation
    punc_cat = {"Pc", "Pd", "Ps", "Pe", "Pi", "Pf", "Po"}
    if all(unicodedata.category(x) in punc_cat for x in token):
        feature_list.append(f"{preffix}_PUNCTUATION")

    feature_list.append(f"{preffix}_WORD_" + token)
    return feature_list

def feature_func(tokens, idx):
    token = tokens[idx]
    
    token_prev = None
    token_next = None
    
    try:
        token_prev = tokens[idx-1]
    except Exception:
        pass
    
    try:
        token_next = tokens[idx+1]
    except Exception:
        pass
    
    curr_feature_list = []
    prev_feature_list = []
    next_feature_list = []
    
    if token:
        curr_feature_list = get_basic_feature(token, 'CURR')
    
    if token_prev:
        prev_feature_list = get_context_feature(token_prev, 'PREV')
    
    if token_next:
        next_feature_list = get_context_feature(token_next, 'NEXT')
        
    
    feature = curr_feature_list + prev_feature_list
    return feature

# %%
ct = CRFTagger(feature_func=feature_func)
ct.train(train_sentences, model_file)

# %%
ct = CRFTagger(feature_func=feature_func)
ct.set_model_file(model_file)
ct.evaluate(test_sentences)
# Out:
# 0.9503561407295489

# %% [markdown]
# ### Transformational model

# %%
backoff = RegexpTagger([
    (r'^-?[0-9]+(.[0-9]+)?$', 'CD'),   # cardinal numbers
    (r'(The|the|A|a|An|an)$', 'AT'),   # articles
    (r'.*able$', 'JJ'),                # adjectives
    (r'.*ness$', 'NN'),                # nouns formed from adjectives
    (r'.*ly$', 'RB'),                  # adverbs
    (r'.*s$', 'NNS'),                  # plural nouns
    (r'.*ing$', 'VBG'),                # gerunds
    (r'.*ed$', 'VBD'),                 # past tense verbs
    (r'.*', 'NN')                      # nouns (default)
])

baseline = backoff
Template._cleartemplates() #clear any templates created in earlier tests
templates = [Template(Pos([-1])), Template(Pos([-1]), Word([0]))]

# %%
tagger1 = ct

eval_scores = []

for i in range(20):
    tt = BrillTaggerTrainer(tagger1, templates, trace=3)
    tagger1 = tt.train(train_sentences, max_rules=10)
    score = tagger1.evaluate(test_sentences)
    eval_scores.append(score)
# Out:
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2989 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
#    4   4   0   0  | NN->JJR if Pos:DT@[-1] & Word:broader@[0]
#    3   3   0   2  | RP->RB if Pos:,@[-1]
#    3   3   0   0  | VBG->VB if Pos:TO@[-1]
#    3   4   1   0  | IN->RB if Pos:,@[-1] & Word:down@[0]
#    3   4   1   0  | IN->RB if Pos:,@[-1] & Word:up@[0]
#    3   3   0   0  | JJ->NN if Pos:DT@[-1] & Word:editorial@[0]
#    3   3   0   0  | JJ->NN if Pos:JJ@[-1] & Word:chemical@[0]
#    3   3   0   0  | NN->JJ if Pos:CC@[-1] & Word:stock-index@[0]
#    3   3   0   0  | NN->JJ if Pos:DT@[-1] & Word:nice@[0]
#    3   3   0   0  | NNP->CC if Pos:NNP@[-1] & Word:v.@[0]
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2973 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
#    3   3   0   0  | NNP->JJ if Pos:NNP@[-1] & Word:York-based@[0]
#    3   3   0   0  | NNP->NN if Pos:IN@[-1] & Word:Chapter@[0]
#    2   2   0   0  | EX->RB if Pos:NNP@[-1]
#    2   2   0   0  | EX->RB if Pos:NNS@[-1]
#    2   2   0   0  | POS->VBZ if Pos:EX@[-1]
#    2   2   0   0  | POS->VBZ if Pos:IN@[-1]
#    2   2   0   0  | POS->VBZ if Pos:WP@[-1]
#    2   2   0   0  | DT->JJ if Pos:IN@[-1] & Word:new-home@[0]
#    2   2   0   0  | IN->JJ if Pos:VBD@[-1] & Word:off@[0]
#    2   2   0   0  | IN->VBP if Pos:``@[-1] & Word:Do@[0]
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2955 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
#    2   2   0   0  | JJ->DT if Pos::@[-1] & Word:any@[0]
#    2   2   0   0  | JJ->JJS if Pos:DT@[-1] & Word:worst@[0]
#    2   2   0   0  | JJ->NN if Pos:DT@[-1] & Word:premiere@[0]
#    2   2   0   0  | JJ->NN if Pos:DT@[-1] & Word:signal@[0]
#    2   2   0   0  | JJ->NN if Pos:IN@[-1] & Word:interest-rate@[0]
#    2   2   0   0  | JJ->NN if Pos:JJ@[-1] & Word:alternative@[0]
#    2   2   0   0  | JJ->NN if Pos:JJ@[-1] & Word:incentive@[0]
#    2   2   0   0  | JJ->PRP$ if Pos:``@[-1] & Word:My@[0]
#    2   2   0   0  | JJ->RB if Pos:VBZ@[-1] & Word:just@[0]
#    2   2   0   0  | JJ->VBN if Pos:IN@[-1] & Word:prolonged@[0]
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2941 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
#    2   2   0   0  | JJR->RBR if Pos:NNS@[-1] & Word:earlier@[0]
#    2   2   0   0  | JJS->JJ if Pos:POS@[-1] & Word:second-largest@[0]
#    2   2   0   0  | MD->RB if Pos:NN@[-1] & Word:right@[0]
#    2   2   0   0  | NN->JJ if Pos:DT@[-1] & Word:line-item@[0]
#    2   2   0   0  | NN->JJ if Pos:DT@[-1] & Word:very@[0]
#    2   2   0   0  | NN->JJ if Pos:POS@[-1] & Word:nine-member@[0]
#    2   2   0   0  | NN->JJ if Pos:PRP$@[-1] & Word:low-ability@[0]
#    2   2   0   0  | NN->JJ if Pos:VBD@[-1] & Word:guilty@[0]
#    2   2   0   0  | NN->JJR if Pos:DT@[-1] & Word:greater@[0]
#    2   2   0   0  | NN->JJR if Pos:DT@[-1] & Word:longer@[0]
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2928 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
#    2   2   0   0  | NN->JJR if Pos:IN@[-1] & Word:less@[0]
#    2   2   0   0  | NN->NNS if Pos:DT@[-1] & Word:media@[0]
#    2   2   0   0  | NN->RB if Pos:CD@[-1] & Word:p.m@[0]
#    2   2   0   0  | NN->RB if Pos:VBN@[-1] & Word:forward@[0]
#    2   2   0   0  | NN->VBG if Pos:DT@[-1] & Word:working@[0]
#    2   2   0   0  | NNP->CD if Pos:NNP@[-1] & Word:One@[0]
#    2   2   0   0  | NNP->DT if Pos::@[-1] & Word:The@[0]
#    2   2   0   0  | NNP->IN if Pos:NNP@[-1] & Word:OF@[0]
#    2   2   0   0  | NNP->NN if Pos:NN@[-1] & Word:F@[0]
#    2   2   0   0  | NNP->NN if Pos:NNP@[-1] & Word:Civilization@[0]
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2916 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
#    2   2   0   0  | NNP->NNPS if Pos:DT@[-1] & Word:Writers@[0]
#    2   2   0   0  | NNP->NNPS if Pos:NNP@[-1] & Word:Stores@[0]
#    2   2   0   0  | NNS->JJ if Pos:JJ@[-1] & Word:capital-markets@[0]
#    2   2   0   0  | NNS->NN if Pos:DT@[-1] & Word:social-studies@[0]
#    2   2   0   0  | NNS->NN if Pos:JJ@[-1] & Word:lens@[0]
#    2   2   0   0  | NNS->NN if Pos:JJ@[-1] & Word:series@[0]
#    2   2   0   0  | NNS->NNPS if Pos:DT@[-1] & Word:Giants@[0]
#    2   2   0   0  | NNS->VBZ if Pos:NN@[-1] & Word:fills@[0]
#    2   2   0   0  | NNS->VBZ if Pos:NN@[-1] & Word:suggests@[0]
#    2   2   0   0  | RB->RP if Pos:-NONE-@[-1] & Word:together@[0]
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2905 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
#    2   2   0   0  | RB->VBN if Pos:VBP@[-1] & Word:got@[0]
#    2   2   0   0  | VB->RB if Pos:MD@[-1] & Word:no@[0]
#    2   2   0   0  | JJR->RBR if Pos:RB@[-1] & Word:longer@[0]
#    2   2   0   0  | VB->VBD if Pos:CC@[-1] & Word:gave@[0]
#    2   2   0   0  | VBD->JJ if Pos:NN@[-1] & Word:capped@[0]
#    2   2   0   0  | VBD->JJ if Pos:NN@[-1] & Word:leveraged@[0]
#    2   2   0   0  | VBG->IN if Pos:-NONE-@[-1] & Word:during@[0]
#    2   2   0   0  | VBG->JJ if Pos:NNS@[-1] & Word:outstanding@[0]
#    2   2   0   0  | VBG->JJ if Pos:VBP@[-1] & Word:willing@[0]
#    2   2   0   0  | VBG->JJ if Pos:VBZ@[-1] & Word:interesting@[0]
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2892 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
#    2   2   0   0  | VBG->NN if Pos:RB@[-1] & Word:everything@[0]
#    2   2   0   0  | VBN->JJ if Pos:VBZ@[-1] & Word:62%-owned@[0]
#    2   2   0   0  | VBN->NN if Pos:DT@[-1] & Word:need@[0]
#    2   2   0   0  | VBZ->RB if Pos:PRP@[-1] & Word:always@[0]
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
# TBL train (fast) (seqs: 3000; tokens: 77511; tpls: 2; min score: 2; min acc: None)
# Finding initial useful rules...
#     Found 2886 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------

# %%
plt.plot(list(range(len(eval_scores))), eval_scores)
plt.xlabel("Nombre d'entraînement")
plt.ylabel('Score')
plt.show()

# %%
eval_scores.__len__()
# Out:
# 20

# %%
eval_scores = [0.9513921864882365,
 0.9514353550615152,
 0.9515648607813512,
 0.9516511979279085,
 0.9516511979279085,
 0.9517375350744658,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804,
 0.9519102093675804]

# %%
eval_scores
# Out:
# [0.9503561407295489,
#  0.9513921864882365,
#  0.9514353550615152,
#  0.9515648607813512,
#  0.9516511979279085,
#  0.9516511979279085,
#  0.9517375350744658,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804,
#  0.9519102093675804]
